# %%
import tensorflow as tf
import pandas as pd 
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt 
import os 
import pathlib 
import random

# %%
path = '/content/drive/MyDrive/PROJECTS/breast cancer detection/Dataset_BUSI_with_GT'
data_dir = pathlib.Path(path)

# %%
class_names = np.array(sorted([item.name for item in data_dir.glob("*")]))
class_names
# Out:
# array(['benign', 'malignant', 'normal'], dtype='<U9')

# %%
benignPath = os.path.join(data_dir,'bening')
malignantPath = os.path.join(data_dir,'malignant')
normalPath = os.path.join(data_dir,'normal')

# %%
imageCount = len(list(data_dir.glob('*/*.png')))
imageCount
# Out:
# 1578

# %%
plt.figure(figsize=(15,15))

for i in range(25):
    plt.subplot(5,5,i+1)
    random_class = random.choice(class_names)
    img = plt.imread(random.choice(list(data_dir.glob(random_class+"/*.png"))))
    plt.xticks([])
    plt.yticks([])
    plt.title(random_class)
    plt.imshow(img)

# %%
from pathlib import Path
import imghdr

data_dir = '../input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/'
image_extensions = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Define image size and batch size
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# Define directory path and split the data into training and validation sets
data_dir = "/content/drive/MyDrive/PROJECTS/breast cancer detection/Dataset_BUSI_with_GT"
train_data = image_dataset_from_directory(
                  data_dir,
                  validation_split=0.2,
                  subset="training",
                  seed=123,
                  image_size=IMG_SIZE,
                  batch_size=BATCH_SIZE
             )
val_data = image_dataset_from_directory(
                  data_dir,
                  validation_split=0.2,
                  subset="validation",
                  seed=123,
                  image_size=IMG_SIZE,
                  batch_size=BATCH_SIZE
             )
# Out:
# Found 1578 files belonging to 3 classes.
# Using 1263 files for training.
# Found 1578 files belonging to 3 classes.
# Using 315 files for validation.

# %%
from tensorflow.keras import layers 
model = tf.keras.Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
    
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
    
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
    
  layers.Dropout(0.5),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(3,activation="softmax")
])

# %%
model.compile(optimizer="Adam",
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
            metrics=["accuracy"])

# %%
epochs = 100
history = model.fit(train_data,
                    epochs=epochs,
                    validation_data=val_data, 
                    batch_size=batch_size)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 9s 208ms/step - loss: 0.0151 - accuracy: 0.9968 - val_loss: 1.4603 - val_accuracy: 0.7968
# Epoch 2/100
# 40/40 [==============================] - 9s 196ms/step - loss: 0.0211 - accuracy: 0.9937 - val_loss: 1.5126 - val_accuracy: 0.7841
# Epoch 3/100
# 40/40 [==============================] - 8s 165ms/step - loss: 0.0158 - accuracy: 0.9976 - val_loss: 1.4232 - val_accuracy: 0.7905
# Epoch 4/100
# 40/40 [==============================] - 10s 214ms/step - loss: 0.0085 - accuracy: 0.9984 - val_loss: 1.6089 - val_accuracy: 0.8127
# Epoch 5/100
# 40/40 [==============================] - 8s 168ms/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 1.5279 - val_accuracy: 0.8000
# Epoch 6/100
# 40/40 [==============================] - 8s 165ms/step - loss: 0.0087 - accuracy: 0.9968 - val_loss: 1.6250 - val_accuracy: 0.8032
# Epoch 7/100
# 40/40 [==============================] - 9s 203ms/step - loss: 0.0413 - accuracy: 0.9945 - val_loss: 1.6553 - val_accuracy: 0.7714
# Epoch 8/100
# 40/40 [==============================] - 9s 191ms/step - loss: 0.0359 - accuracy: 0.9905 - val_loss: 1.4964 - val_accuracy: 0.7714
# Epoch 9/100
# 40/40 [==============================] - 8s 167ms/step - loss: 0.0272 - accuracy: 0.9913 - val_loss: 1.7112 - val_accuracy: 0.7841
# Epoch 10/100
# 40/40 [==============================] - 9s 169ms/step - loss: 0.0181 - accuracy: 0.9952 - val_loss: 1.6470 - val_accuracy: 0.7810
# Epoch 11/100
# 40/40 [==============================] - 9s 204ms/step - loss: 0.0085 - accuracy: 0.9968 - val_loss: 1.7262 - val_accuracy: 0.7683
# Epoch 12/100
# 40/40 [==============================] - 8s 168ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 1.7573 - val_accuracy: 0.7810
# Epoch 13/100
# 40/40 [==============================] - 8s 170ms/step - loss: 0.0040 - accuracy: 0.9976 - val_loss: 1.7834 - val_accuracy: 0.7810
# Epoch 14/100
# 40/40 [==============================] - 9s 190ms/step - loss: 0.0042 - accuracy: 0.9984 - val_loss: 1.8396 - val_accuracy: 0.7937
# Epoch 15/100
# 40/40 [==============================] - 9s 206ms/step - loss: 0.0024 - accuracy: 0.9984 - val_loss: 2.0044 - val_accuracy: 0.7937
# Epoch 16/100
# 40/40 [==============================] - 8s 168ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 2.0658 - val_accuracy: 0.7937
# Epoch 17/100
# 40/40 [==============================] - 8s 169ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 1.9793 - val_accuracy: 0.7810
# Epoch 18/100
# 40/40 [==============================] - 9s 206ms/step - loss: 0.0078 - accuracy: 0.9968 - val_loss: 2.2296 - val_accuracy: 0.7746
# Epoch 19/100
# 40/40 [==============================] - 8s 178ms/step - loss: 0.0243 - accuracy: 0.9945 - val_loss: 1.7709 - val_accuracy: 0.7746
# Epoch 20/100
# 40/40 [==============================] - 9s 170ms/step - loss: 0.0171 - accuracy: 0.9960 - val_loss: 1.7734 - val_accuracy: 0.7587
# Epoch 21/100
# 40/40 [==============================] - 9s 203ms/step - loss: 0.0119 - accuracy: 0.9952 - val_loss: 1.7438 - val_accuracy: 0.7778
# Epoch 22/100
# 40/40 [==============================] - 8s 164ms/step - loss: 0.0121 - accuracy: 0.9968 - val_loss: 1.7704 - val_accuracy: 0.7873
# Epoch 23/100
# 40/40 [==============================] - 9s 200ms/step - loss: 0.0169 - accuracy: 0.9960 - val_loss: 1.9476 - val_accuracy: 0.7810
# Epoch 24/100
# 40/40 [==============================] - 9s 191ms/step - loss: 0.0114 - accuracy: 0.9976 - val_loss: 1.8623 - val_accuracy: 0.7873
# Epoch 25/100
# 40/40 [==============================] - 8s 165ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 2.1169 - val_accuracy: 0.7968
# Epoch 26/100
# 40/40 [==============================] - 9s 205ms/step - loss: 0.0168 - accuracy: 0.9952 - val_loss: 1.7985 - val_accuracy: 0.7905
# Epoch 27/100
# 40/40 [==============================] - 9s 201ms/step - loss: 0.0097 - accuracy: 0.9952 - val_loss: 1.7154 - val_accuracy: 0.7746
# Epoch 28/100
# 40/40 [==============================] - 8s 167ms/step - loss: 0.0191 - accuracy: 0.9960 - val_loss: 1.6737 - val_accuracy: 0.7778
# Epoch 29/100
# 40/40 [==============================] - 9s 170ms/step - loss: 0.0310 - accuracy: 0.9960 - val_loss: 1.6547 - val_accuracy: 0.7841
# Epoch 30/100
# 40/40 [==============================] - 9s 202ms/step - loss: 0.0248 - accuracy: 0.9929 - val_loss: 1.6455 - val_accuracy: 0.7937
# Epoch 31/100
# 40/40 [==============================] - 9s 194ms/step - loss: 0.0213 - accuracy: 0.9921 - val_loss: 1.5559 - val_accuracy: 0.7810
# Epoch 32/100
# 40/40 [==============================] - 7s 161ms/step - loss: 0.0097 - accuracy: 0.9937 - val_loss: 2.1370 - val_accuracy: 0.7619
# Epoch 33/100
# 40/40 [==============================] - 8s 164ms/step - loss: 0.0128 - accuracy: 0.9945 - val_loss: 1.9202 - val_accuracy: 0.8000
# Epoch 34/100
# 40/40 [==============================] - 9s 202ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 2.1082 - val_accuracy: 0.7873
# Epoch 35/100
# 40/40 [==============================] - 8s 163ms/step - loss: 0.0026 - accuracy: 0.9984 - val_loss: 2.4615 - val_accuracy: 0.7937
# Epoch 36/100
# 40/40 [==============================] - 8s 168ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 2.4004 - val_accuracy: 0.7841
# Epoch 37/100
# 40/40 [==============================] - 9s 203ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 2.3496 - val_accuracy: 0.7873
# Epoch 38/100
# 40/40 [==============================] - 9s 192ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 2.5448 - val_accuracy: 0.7873
# Epoch 39/100
# 40/40 [==============================] - 9s 196ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 2.5989 - val_accuracy: 0.7905
# Epoch 40/100
# 40/40 [==============================] - 9s 189ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 2.5529 - val_accuracy: 0.7905
# Epoch 41/100
# 40/40 [==============================] - 9s 205ms/step - loss: 0.0048 - accuracy: 0.9968 - val_loss: 2.2170 - val_accuracy: 0.7810
# Epoch 42/100
# 40/40 [==============================] - 8s 167ms/step - loss: 0.0086 - accuracy: 0.9952 - val_loss: 2.5152 - val_accuracy: 0.7841
# Epoch 43/100
# 40/40 [==============================] - 9s 190ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 2.7006 - val_accuracy: 0.7905
# Epoch 44/100
# 40/40 [==============================] - 9s 201ms/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 2.6480 - val_accuracy: 0.7873
# Epoch 45/100
# 40/40 [==============================] - 8s 167ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 2.7360 - val_accuracy: 0.7841
# Epoch 46/100
# 40/40 [==============================] - 9s 174ms/step - loss: 0.0054 - accuracy: 0.9968 - val_loss: 2.3584 - val_accuracy: 0.7905
# Epoch 47/100
# 40/40 [==============================] - 9s 197ms/step - loss: 0.0207 - accuracy: 0.9945 - val_loss: 2.3509 - val_accuracy: 0.7587
# Epoch 48/100
# 40/40 [==============================] - 8s 166ms/step - loss: 0.0143 - accuracy: 0.9968 - val_loss: 2.4607 - val_accuracy: 0.7683
# Epoch 49/100
# 40/40 [==============================] - 9s 183ms/step - loss: 0.0183 - accuracy: 0.9913 - val_loss: 2.4317 - val_accuracy: 0.7714
# Epoch 50/100
# 40/40 [==============================] - 9s 200ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 2.2551 - val_accuracy: 0.7746
# Epoch 51/100
# 40/40 [==============================] - 8s 165ms/step - loss: 0.0079 - accuracy: 0.9968 - val_loss: 2.3011 - val_accuracy: 0.7746
# Epoch 52/100
# 40/40 [==============================] - 9s 201ms/step - loss: 0.0228 - accuracy: 0.9929 - val_loss: 2.8187 - val_accuracy: 0.7746
# Epoch 53/100
# 40/40 [==============================] - 9s 205ms/step - loss: 0.0417 - accuracy: 0.9905 - val_loss: 2.6240 - val_accuracy: 0.7841
# Epoch 54/100
# 40/40 [==============================] - 8s 165ms/step - loss: 0.0158 - accuracy: 0.9945 - val_loss: 2.5462 - val_accuracy: 0.7968
# Epoch 55/100
# 40/40 [==============================] - 9s 205ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 2.7570 - val_accuracy: 0.7714
# Epoch 56/100
# 40/40 [==============================] - 8s 177ms/step - loss: 0.0128 - accuracy: 0.9968 - val_loss: 2.7205 - val_accuracy: 0.7810
# Epoch 57/100
# 40/40 [==============================] - 8s 165ms/step - loss: 0.0129 - accuracy: 0.9960 - val_loss: 2.7423 - val_accuracy: 0.7746
# Epoch 58/100
# 40/40 [==============================] - 9s 204ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 2.9158 - val_accuracy: 0.8000
# Epoch 59/100
# 40/40 [==============================] - 9s 191ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 2.6186 - val_accuracy: 0.7968
# Epoch 60/100
# 40/40 [==============================] - 8s 166ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 2.5622 - val_accuracy: 0.8000
# Epoch 61/100
# 40/40 [==============================] - 9s 198ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 2.7946 - val_accuracy: 0.8063
# Epoch 62/100
# 40/40 [==============================] - 9s 193ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 2.8044 - val_accuracy: 0.8032
# Epoch 63/100
# 40/40 [==============================] - 8s 163ms/step - loss: 0.0014 - accuracy: 0.9992 - val_loss: 2.7477 - val_accuracy: 0.7968
# Epoch 64/100
# 40/40 [==============================] - 9s 200ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 2.8325 - val_accuracy: 0.8063
# Epoch 65/100
# 40/40 [==============================] - 8s 168ms/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 2.8731 - val_accuracy: 0.8063
# Epoch 66/100
# 40/40 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 2.9393 - val_accuracy: 0.7873
# Epoch 67/100
# 40/40 [==============================] - 9s 202ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 2.9699 - val_accuracy: 0.7873
# Epoch 68/100
# 40/40 [==============================] - 8s 163ms/step - loss: 0.0013 - accuracy: 0.9984 - val_loss: 3.0168 - val_accuracy: 0.7810
# Epoch 69/100
# 40/40 [==============================] - 9s 186ms/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 3.0161 - val_accuracy: 0.7810
# Epoch 70/100
# 40/40 [==============================] - 9s 200ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.1253 - val_accuracy: 0.7841
# Epoch 71/100
# 40/40 [==============================] - 7s 163ms/step - loss: 0.0014 - accuracy: 0.9984 - val_loss: 3.1058 - val_accuracy: 0.7778
# Epoch 72/100
# 40/40 [==============================] - 9s 202ms/step - loss: 0.0014 - accuracy: 0.9992 - val_loss: 3.0464 - val_accuracy: 0.7905
# Epoch 73/100
# 40/40 [==============================] - 9s 196ms/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 3.1276 - val_accuracy: 0.7937
# Epoch 74/100
# 40/40 [==============================] - 8s 167ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.1527 - val_accuracy: 0.7968
# Epoch 75/100
# 40/40 [==============================] - 9s 200ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.1497 - val_accuracy: 0.7905
# Epoch 76/100
# 40/40 [==============================] - 8s 165ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.1663 - val_accuracy: 0.7937
# Epoch 77/100
# 40/40 [==============================] - 8s 167ms/step - loss: 0.0013 - accuracy: 0.9984 - val_loss: 3.2303 - val_accuracy: 0.7905
# Epoch 78/100
# 40/40 [==============================] - 9s 201ms/step - loss: 0.0012 - accuracy: 0.9984 - val_loss: 3.2713 - val_accuracy: 0.7937
# Epoch 79/100
# 40/40 [==============================] - 9s 195ms/step - loss: 0.0013 - accuracy: 0.9984 - val_loss: 3.4079 - val_accuracy: 0.7841
# Epoch 80/100
# 40/40 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.4029 - val_accuracy: 0.7841
# Epoch 81/100
# 40/40 [==============================] - 9s 201ms/step - loss: 0.0014 - accuracy: 0.9984 - val_loss: 2.8478 - val_accuracy: 0.7841
# Epoch 82/100
# 40/40 [==============================] - 9s 194ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 2.9496 - val_accuracy: 0.7968
# Epoch 83/100
# 40/40 [==============================] - 8s 162ms/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 3.1115 - val_accuracy: 0.7937
# Epoch 84/100
# 40/40 [==============================] - 9s 211ms/step - loss: 0.0012 - accuracy: 0.9984 - val_loss: 3.1443 - val_accuracy: 0.7968
# Epoch 85/100
# 40/40 [==============================] - 8s 168ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.1681 - val_accuracy: 0.7968
# Epoch 86/100
# 40/40 [==============================] - 8s 165ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.1903 - val_accuracy: 0.7937
# Epoch 87/100
# 40/40 [==============================] - 8s 168ms/step - loss: 0.0012 - accuracy: 0.9984 - val_loss: 3.2381 - val_accuracy: 0.7968
# Epoch 88/100
# 40/40 [==============================] - 9s 205ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.2418 - val_accuracy: 0.7968
# Epoch 89/100
# 40/40 [==============================] - 8s 164ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.2145 - val_accuracy: 0.7937
# Epoch 90/100
# 40/40 [==============================] - 8s 166ms/step - loss: 0.0012 - accuracy: 0.9984 - val_loss: 3.1728 - val_accuracy: 0.8000
# Epoch 91/100
# 40/40 [==============================] - 9s 199ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.1858 - val_accuracy: 0.8032
# Epoch 92/100
# 40/40 [==============================] - 8s 172ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.2732 - val_accuracy: 0.7937
# Epoch 93/100
# 40/40 [==============================] - 9s 174ms/step - loss: 0.0012 - accuracy: 0.9984 - val_loss: 3.2810 - val_accuracy: 0.7905
# Epoch 94/100
# 40/40 [==============================] - 9s 204ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.3060 - val_accuracy: 0.7905
# Epoch 95/100
# 40/40 [==============================] - 9s 196ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.5202 - val_accuracy: 0.7905
# Epoch 96/100
# 40/40 [==============================] - 8s 164ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.4489 - val_accuracy: 0.7905
# Epoch 97/100
# 40/40 [==============================] - 9s 204ms/step - loss: 0.0012 - accuracy: 0.9984 - val_loss: 3.3959 - val_accuracy: 0.7873
# Epoch 98/100
# 40/40 [==============================] - 9s 197ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 3.2915 - val_accuracy: 0.7937
# Epoch 99/100
# 40/40 [==============================] - 8s 164ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.3322 - val_accuracy: 0.7905
# Epoch 100/100
# 40/40 [==============================] - 8s 167ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.4960 - val_accuracy: 0.7905

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history.history['accuracy']
val_acc =  history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,acc,label='Accuracy')
plt.plot(epochs_range,val_acc,label="Validation Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs_range,loss,label='Loss')
plt.plot(epochs_range,val_loss,label="Validation Loss")
plt.legend()
plt.show()

# %%
model.evaluate(val_data)
# Out:
# 10/10 [==============================] - 1s 32ms/step - loss: 3.4960 - accuracy: 0.7905
# [3.4960155487060547, 0.7904762029647827]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 28, 28, 64)        0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 128)               6422656
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 6,446,627
# Trainable params: 6,446,627
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=(15, 15))
class_names = val_data.class_names
result = ' | False'
for images, labels in val_data.take(1):
    for i in range(25):
        
        ax = plt.subplot(5, 5, i + 1)
        img = images[i].numpy().astype("uint8")
        img = tf.expand_dims(img, axis=0)
        
        predictions = model.predict(img)
        predicted_class = np.argmax(predictions)
        if class_names[predicted_class] == class_names[labels[i]]:
            result = ' | TRUE'
            
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[predicted_class]+result  )
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 41ms/step
